# %% [markdown]
# ## Notebook to check trends within data and offer more insight into the daily covid-19 trends.

# %%
# %store -r covid_confirmed_dataset
# %store -r covid_deaths_dataset
# %store -r covid_recovered_dataset

# %%
covid_confirmed_dataset.info()
covid_deaths_dataset.info()
covid_recovered_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 59 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      140 non-null    datetime64[ns]
#  1   Alabama                   140 non-null    object
#  2   Alaska                    140 non-null    object
#  3   American Samoa            140 non-null    object
#  4   Arizona                   140 non-null    object
#  5   Arkansas                  140 non-null    object
#  6   California                140 non-null    object
#  7   Colorado                  140 non-null    object
#  8   Connecticut               140 non-null    object
#  9   Delaware                  140 non-null    object
#  10  Diamond Princess          140 non-null    object
#  11  District of Columbia      140 non-null    object
#  12  Florida                   140 non-null    object
# ...

# %%
covid_confirmed_dataset.describe()
# Out:
#                        Date   Alabama  Alaska  American Samoa   Arizona  \
# count                   140     140.0   140.0           140.0     140.0
# unique                  140     140.0   140.0             1.0     140.0
# top     2020-10-23 00:00:00  136703.0  4741.0             0.0  234906.0
# freq                      1       1.0     1.0           140.0       1.0
# first   2020-06-28 00:00:00       NaN     NaN             NaN       NaN
# last    2020-11-14 00:00:00       NaN     NaN             NaN       NaN
#
#         Arkansas  California  Colorado  Connecticut  Delaware  ...  Tennessee  \
# count      140.0       140.0     140.0        140.0     140.0  ...      140.0
# unique     140.0       140.0     138.0        100.0     139.0  ...      140.0
# top      56574.0    546814.0   58287.0      53365.0   18308.0  ...   128511.0
# freq         1.0         1.0       2.0          4.0       2.0  ...        1.0
# ...

# %%
covid_deaths_dataset.describe()
# Out:
#                        Date  Alabama  Alaska  American Samoa  Arizona  \
# count                   140    140.0   140.0           140.0    140.0
# unique                  140    125.0    50.0             1.0    132.0
# top     2020-10-23 00:00:00   2501.0    17.0             0.0   5759.0
# freq                      1      3.0    11.0           140.0      3.0
# first   2020-06-28 00:00:00      NaN     NaN             NaN      NaN
# last    2020-11-14 00:00:00      NaN     NaN             NaN      NaN
#
#         Arkansas  California  Colorado  Connecticut  Delaware  ...  Tennessee  \
# count      140.0       140.0     140.0        140.0     140.0  ...      140.0
# unique     138.0       140.0     122.0         83.0      84.0  ...      139.0
# top        357.0     13823.0    1701.0       4468.0     593.0  ...     3353.0
# freq         2.0         1.0       4.0          5.0       6.0  ...        2.0
# first        NaN         NaN       NaN          NaN       NaN  ...        NaN
# ...

# %%
covid_recovered_dataset.describe()
# Out:
#                        Date  Alabama  Alaska  American Samoa  Arizona  \
# count                   140    140.0   140.0           140.0    140.0
# unique                  140     21.0   127.0             1.0    140.0
# top     2020-10-23 00:00:00  67948.0  7161.0             0.0  26736.0
# freq                      1      8.0     5.0           140.0      1.0
# first   2020-06-28 00:00:00      NaN     NaN             NaN      NaN
# last    2020-11-14 00:00:00      NaN     NaN             NaN      NaN
#
#         Arkansas  California  Colorado  Connecticut  Delaware  ...  Tennessee  \
# count      140.0       140.0     140.0        140.0     140.0  ...      140.0
# unique     125.0         1.0     136.0         18.0     133.0  ...      139.0
# top      64145.0         0.0    4669.0       9800.0    7362.0  ...    57239.0
# freq         3.0       140.0       2.0         24.0       4.0  ...        2.0
# first        NaN         NaN       NaN          NaN       NaN  ...        NaN
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

covid_confirmed_dataset.apply(pd.to_numeric, errors='ignore').loc[:, 'Alabama':].hist(bins=50, figsize=(20, 15))

plt.show()

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

covid_deaths_dataset.apply(pd.to_numeric, errors='ignore').loc[:, 'Alabama':].hist(bins=50, figsize=(20, 15))

plt.show()

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

covid_recovered_dataset.apply(pd.to_numeric, errors='ignore').loc[:, 'Alabama':].hist(bins=50, figsize=(20, 15))

plt.show()

# %% [markdown]
# ## Discover and Visualize the Data to Gain Deeper Insights

# %% [markdown]
# I will have to do this exploration completely separately for each of the response variables to avoid any confusion.

# %% [markdown]
# #### 1. Testing and Training Sets

# %%
# split the dataset into training and testing sets

from sklearn.model_selection import train_test_split

train_set_confirmed, test_set_confirmed = train_test_split(covid_confirmed_dataset, test_size = 0.2, random_state = 100)
train_set_deaths, test_set_deaths = train_test_split(covid_deaths_dataset, test_size = 0.2, random_state = 100)
train_set_recovered, test_set_recovered = train_test_split(covid_recovered_dataset, test_size = 0.2, random_state = 100)
